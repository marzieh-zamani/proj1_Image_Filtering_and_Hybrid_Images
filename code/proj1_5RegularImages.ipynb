# %% [markdown]
# # CS 6476 Project 1: Image Filtering and Hybrid Images
#
# All projects in this course will be done with these iPython notebooks. These are convenient ways for you to quickly and easily interact with the code. A notebook contains many blocks of code, each of which can be run independently. You can run a cell with ctrl+enter or shift+enter (to move to the next cell).
#
# If there are any notes you wish to leave for the TAs as they test your code, you may leave them here.
#
# ## Setup

# %%
import cv2
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from utils import vis_hybrid_image, load_image, save_image
from student_code import my_imfilter, create_hybrid_image
# %load_ext autoreload
# %autoreload 2

image1 = load_image('../data/dog.bmp')
image2 = load_image('../data/cat.bmp')

# display the dog and cat images
plt.figure(figsize=(3,3)); plt.imshow((image1*255).astype(np.uint8));
plt.figure(figsize=(3,3)); plt.imshow((image2*255).astype(np.uint8));

# %% [markdown]
# ## Create filter

# %%
cutoff_frequency = 7
filter = cv2.getGaussianKernel(ksize=cutoff_frequency*4+1,
                               sigma=cutoff_frequency)
filter = np.dot(filter, filter.T)

# let's take a look at the filter!
plt.figure(figsize=(4,4)); plt.imshow(filter);

# %% [markdown]
# ## Apply filter to image
# Both functions you need to implement in this project can be found in _student_\__code.py_. Start by implementing _my_\__imfilter_, which takes both a filter and an image, and returns the filtered image. This code block will use your _my_\__imfilter_ function to create and display a blurry version of the dog image.

# %%
blurry_dog = my_imfilter(image1, filter)
plt.figure(); plt.imshow((blurry_dog*255).astype(np.uint8));

# %% [markdown]
# ## Create hybrid image
# Next, implement _create_\__hybrid_\__image_, which takes two images and makes a hybrid image using the low frequency content from one image and the high frequency content from another.

# %%
low_frequencies, high_frequencies, hybrid_image = create_hybrid_image(image1, image2, filter)
vis = vis_hybrid_image(hybrid_image)

# %% [markdown]
# ## ===================== Result #1 =====================

# %% [markdown]
# ## Show results

# %%
plt.figure(); plt.imshow((low_frequencies*255).astype(np.uint8));
plt.figure(); plt.imshow(((high_frequencies+0.5)*255).astype(np.uint8));
plt.figure(figsize=(20, 20)); plt.imshow(vis);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Save results

# %%
save_image('../results/1_low_frequencies.jpg', low_frequencies)
save_image('../results/1_high_frequencies.jpg', high_frequencies+0.5)
#save_image('../results/hybrid_image.jpg', hybrid_image)
save_image('../results/1_hybrid_image_scales.jpg', vis)
# Out:
# True

# %% [markdown]
# ## ===================== Result #2 =====================

# %%
# Load image
image1 = load_image('../data/marilyn.bmp')
image2 = load_image('../data/einstein.bmp')

# Create filter
cutoff_frequency = 3
filter3 = cv2.getGaussianKernel(ksize=29,
                               sigma=cutoff_frequency)
filter3 = np.dot(filter3, filter3.T)

# Create hybrid image
low_frequencies, high_frequencies, hybrid_image = create_hybrid_image(image1, image2, filter3)
vis = vis_hybrid_image(hybrid_image)

# Plot results
plt.figure(); plt.imshow((low_frequencies*255).astype(np.uint8));
plt.figure(); plt.imshow(((high_frequencies+0.5)*255).astype(np.uint8));
plt.figure(figsize=(20, 20)); plt.imshow(vis);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
save_image('../results/2_s3_low_frequencies.jpg', low_frequencies)
save_image('../results/2_s3_high_frequencies.jpg', high_frequencies+0.5)
save_image('../results/2_s3_hybrid_image_scales.jpg', vis)
# Out:
# True

# %% [markdown]
# ## ===================== Result #3 =====================

# %%
# Load image
image1 = load_image('../data/submarine.bmp')
image2 = load_image('../data/fish.bmp')

# Create filter
cutoff_frequency = 2
filter2 = cv2.getGaussianKernel(ksize=29,
                               sigma=cutoff_frequency)
filter2 = np.dot(filter2, filter2.T)

# Create hybrid image
low_frequencies, high_frequencies, hybrid_image = create_hybrid_image(image1, image2, filter2)
vis = vis_hybrid_image(hybrid_image)

# Plot results
plt.figure(); plt.imshow((low_frequencies*255).astype(np.uint8));
plt.figure(); plt.imshow(((high_frequencies+0.5)*255).astype(np.uint8));
plt.figure(figsize=(20, 20)); plt.imshow(vis);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
save_image('../results/3_s2_low_frequencies.jpg', low_frequencies)
save_image('../results/3_s2_high_frequencies.jpg', high_frequencies+0.5)
save_image('../results/3_s2_hybrid_image_scales.jpg', vis)
# Out:
# True

# %% [markdown]
# ## ===================== Result #4 =====================

# %%
# Load image
image1 = load_image('../data/bird.bmp')
image2 = load_image('../data/plane.bmp')

# Create filter
cutoff_frequency = 4
filter4 = cv2.getGaussianKernel(ksize=29,
                               sigma=cutoff_frequency)
filter4 = np.dot(filter4, filter4.T)

# Create hybrid image
low_frequencies, high_frequencies, hybrid_image = create_hybrid_image(image1, image2, filter4)
vis = vis_hybrid_image(hybrid_image)

# Plot results
plt.figure(); plt.imshow((low_frequencies*255).astype(np.uint8));
plt.figure(); plt.imshow(((high_frequencies+0.5)*255).astype(np.uint8));
plt.figure(figsize=(20, 20)); plt.imshow(vis);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
save_image('../results/4_s4_low_frequencies.jpg', low_frequencies)
save_image('../results/4_s4_high_frequencies.jpg', high_frequencies+0.5)
save_image('../results/4_s4_hybrid_image_scales.jpg', vis)
# Out:
# True

# %% [markdown]
# ## ===================== Result #5 =====================

# %%
# Load image
image1 = load_image('../data/motorcycle.bmp')
image2 = load_image('../data/bicycle.bmp')

# Create filter
cutoff_frequency = 5
filter5 = cv2.getGaussianKernel(ksize=29, sigma=cutoff_frequency)
filter5 = np.dot(filter5, filter5.T)

# Create hybrid image
low_frequencies, high_frequencies, hybrid_image = create_hybrid_image(image1, image2, filter5)
vis = vis_hybrid_image(hybrid_image)

# Plot results
plt.figure(); plt.imshow((low_frequencies*255).astype(np.uint8));
plt.figure(); plt.imshow(((high_frequencies+0.5)*255).astype(np.uint8));
plt.figure(figsize=(20, 20)); plt.imshow(vis);
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
save_image('../results/5_s5_low_frequencies.jpg', low_frequencies)
save_image('../results/5_s5_high_frequencies.jpg', high_frequencies+0.5)
save_image('../results/5_s5_hybrid_image_scales.jpg', vis)
# Out:
# True
